# %%
from deepspeech import Model
import numpy as np
import wave
from IPython.display import clear_output
import librosa
import soundfile as sf
import ffmpeg
import os

model_file_path = 'deepspeech-0.9.3-models.pbmm'
lm_file_path = 'deepspeech-0.9.3-models.scorer'
beam_width = 100
lm_alpha = 0.93
lm_beta = 1.18

model = Model(model_file_path)
model.enableExternalScorer(lm_file_path)
model.setScorerAlphaBeta(lm_alpha, lm_beta)
model.setBeamWidth(beam_width)

stream = model.createStream()

def read_wav_file(filename):
    with wave.open(filename, 'rb') as w:
        rate = w.getframerate()
        frames = w.getnframes()
        buffer = w.readframes(frames)
    return buffer, rate

def convert_audio_to_mono_16k(input_audio_path, output_audio_path):
    audio, sr = librosa.load(input_audio_path, sr=16000)
    sf.write(output_audio_path, audio, 16000)

# Transcription function
def transcribe_streaming(audio_file):
    os.system('cls')
    buffer, rate = read_wav_file(audio_file)
    offset = 0
    batch_size = 8196 
    final_text = ''
    
    while offset < len(buffer):
        end_offset = offset + batch_size
        chunk = buffer[offset:end_offset]
        data16 = np.frombuffer(chunk, dtype=np.int16)
        
        stream.feedAudioContent(data16)
        text = stream.intermediateDecode()
        clear_output(wait=True)
        print(text+"\n") 

        offset = end_offset
    
    final_text += stream.finishStream()
    return final_text

def convert_mp4_to_wav(video_file, output_audio_file):
    try:
        if not os.path.exists(video_file):
            print(f"Error: {video_file} does not exist.")
        else:
            ffmpeg.input(video_file).output(output_audio_file).run()
            print(f"Successfully converted {video_file} to {output_audio_file}")
    except Exception as e:
        print(f"Error: {e}")

video_file = 'Videos/Jimmy.mp4'

output_audio_file = './Assets/Jimmy.wav' 
convert_mp4_to_wav(video_file, output_audio_file)
converted_audio_path = output_audio_file.replace('.wav', '_converted.wav')
print(converted_audio_path)
convert_audio_to_mono_16k(output_audio_file, converted_audio_path)
transcribe_streaming(converted_audio_path)
# Out:
# two years ago a man came into my office he said his name was may he wanted one of my clients to lie for him under oath he offered me money i refused that night said was leaving my office i was attacked bagasse over my head i was hortie i was driven out into the desert and when they pulled a hoof i was kneeling in front of an open grave with a gun pointed at my head that was my introduction to walter white i was terrified mentality saw opportunity shubin and i grabbed it and held it tight and for the next sixteen months my every waking moment was spent building walter white trug and pirodot mister damon stepfather consult mister oakly before you say another word but you're on i believe the court deserves the whole truth you are contradicting your peagrims sworn that basis no affair i know the law here better you do pronaque the recess and we do not need a recess you're unaware satisfy for mister goodman to continue your honor i'd like to petition to withdraw from this case did niederstetter not a sense noisesome in do you swear that the evidence you shall give to the court in this matter shall be the truth the whole truth and nothing but the truth so help you god do mister goodman you are now under oath any full statement you make can be used in prosecution for perjury or obstruction of justice do you understand yes all right in the last twenty four hours have used any alcohol or other grognier medications theoreticians money leomenie had walked in my office at day walter white would have been dead or behind bars within a month an agent trader an aged goes a whole lot of other people would still vilifier white couldn't have done it without me
# "two years ago a man came into my office he said his name was may he wanted one of my clients to lie for him under oath he offered me money i refused that night said was leaving my office i was attacked bagasse over my head i was hortie i was driven out into the desert and when they pulled a hoof i was kneeling in front of an open grave with a gun pointed at my head that was my introduction to walter white i was terrified mentality saw opportunity shubin and i grabbed it and held it tight and for the next sixteen months my every waking moment was spent building walter white trug and pirodot mister damon stepfather consult mister oakly before you say another word but you're on i believe the court deserves the whole truth you are contradicting your peagrims sworn that basis no affair i know the law here better you do pronaque the recess and we do not need a recess you're unaware satisfy for mister goodman to continue your honor i'd like to petition to withdraw from this case did niederstetter not a sense noisesome in do you swear that the evidence you shall give to the court in this matter shall be the truth the whole truth and nothing but the truth so help you god do mister goodman you are now under oath any full statement you make can be used in prosecution for perjury or obstruction of justice do you understand yes all right in the last twenty four hours have used any alcohol or other grognier medications theoreticians money leomenie had walked in my office at day walter white would have been dead or behind bars within a month an agent trader an aged goes a whole lot of other people would still vilifier white couldn't have done it without me"

# %%
import ffmpeg
import os

def convert_mp4_to_wav(video_file, output_audio_file):
    try:
        if not os.path.exists(video_file):
            print(f"Error: {video_file} does not exist.")
        else:
            ffmpeg.input(video_file).output(output_audio_file).run()
            print(f"Successfully converted {video_file} to {output_audio_file}")
    except Exception as e:
        print(f"Error: {e}")

# Check if Assets folder exists
if not os.path.exists('Assets'):
    os.makedirs('Assets')

# Example usage
video_file = 'Biden.mp4' 
output_audio_file = './Assets/Biden.wav' 

convert_mp4_to_wav(video_file, output_audio_file)
converted_audio_path = output_audio_file.replace('.wav', '_converted.wav')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 23
#      20 output_audio_file = './Assets/Biden.wav'
#      22 convert_mp4_to_wav(video_file, output_audio_file)
# ---> 23 transcribe_streaming(output_audio_file)
#
# Cell In[1], line 45, in transcribe_streaming(audio_file)
#      42 chunk = buffer[offset:end_offset]
#      43 data16 = np.frombuffer(chunk, dtype=np.int16)
# ---> 45 stream.feedAudioContent(data16)
#      46 text = stream.intermediateDecode()
#      47 clear_output(wait=True)
#
# File e:\College\Degree\7th Sem\Major Project\Model\project-39\lib\site-packages\deepspeech\__init__.py:218, in Stream.feedAudioContent(self, audio_buffer)
#     216 if not self._impl:
#     217     raise RuntimeError("Stream object is not valid. Trying to feed an already finished stream?")
# --> 218 deepspeech.impl.FeedAudioContent(self._impl, audio_buffer)
#
# File e:\College\Degree\7th Sem\Major Project\Model\project-39\lib\site-packages\deepspeech\impl.py:184, in FeedAudioContent(aSctx, aBuffer)
#     183 def FeedAudioContent(aSctx, aBuffer):
# --> 184     return _impl.FeedAudioContent(aSctx, aBuffer)
#
# KeyboardInterrupt:
